# %%
from textwrap import dedent

from agno.agent import Agent, RunResponse
from agno.models.google import Gemini
from agno.models.openai import OpenAIResponses
from agno.tools.yfinance import YFinanceTools
from agno.utils.pprint import pprint_run_response
from dotenv import load_dotenv
from pydantic import BaseModel, Field
from typing import Literal

load_dotenv()
# Out:
# True

# %%
# model=OpenAIResponses(id='gpt-4.1-mini')
model=Gemini(id='gemini-2.5-flash-preview-04-17')

# %%
data = {
  "area": "semiconductors",
  "tickers": [],       
  "subreddits":     [
  "wallstreetbets",
  "stocks",
  "investing",
  "StockMarket",
  "personalfinance",
  "financialindependence",
  "ValueInvesting",
  "pennystocks",
  "options",
  "SecurityAnalysis",
  "dividends",
  "Bogleheads",
  "ETFs"
],   
  "now_utc": "2025‑05‑31T13:00:00Z"
}

from __future__ import annotations
from datetime import datetime
from typing import List

from pydantic import BaseModel, Field, conint, confloat


class TickerSocialInsight(BaseModel):
    """
    One ticker’s subreddit / social‑media pulse.
    """
    symbol: str = Field(..., description="Ticker symbol, e.g. TSLA.")
    mentions: int = Field(
        ..., description="Total number of posts + comments that mention the ticker in the last 24 h."
    )
    avg_sentiment: float = Field(
        ..., description="Mean polarity across all mentions (−1 … +1)."
    )
    bullish_sentiment: float = Field(
        ..., description="Mean polarity of mentions tagged bullish (> +0.05)."
    )
    bearish_sentiment: float = Field(
        ..., description="Mean polarity of mentions tagged bearish (< −0.05)."
    )
    volume_change_pct: float = Field(
        ..., description="Percentage change in mention volume versus the preceding 24 h window."
    )
    summary: str = Field(
        ..., description="Concise natural‑language takeaway of the social chatter."
    )


class SentimentSnapshot(BaseModel):
    """
    Collection of ticker‑level insights captured at one point in time.
    """
    tickers: List[TickerSocialInsight] = Field(
        ...,
        description="List of social‑sentiment insights for all tickers in the scan."
    )

from reddit import RedditService
from agno.tools.duckduckgo import DuckDuckGoTools
import json

# %%
reddit_data = []
reddit_service = RedditService()
for i in range(0, len(data.get('subreddits'))):
    reddit_data.append(reddit_service.get_posts_with_top_comments(data.get('subreddits')[i], 10))

# %%
reddit_sentiment_agent = Agent(
    model=model,
    tools=[
        YFinanceTools(
           enable_all=True
        ),
        # DuckDuckGoTools()
    ],
    instructions=dedent(f"""
You are the Reddit-Analysis Agent. Follow these steps EXACTLY:

STEP 1: INPUT ANALYSIS
- Parse the input phrase to identify:
  * **Ticker symbols**: 1-5 letter words that look like stock symbols (NVDA, AMD, etc.)
  * **Sector/area keywords**: remaining words that describe industries/sectors

Examples:
- "NVDA AMD" → tickers: [NVDA, AMD], sector: none
- "ai sector" → tickers: [], sector: "ai"  
- "semiconductors" → tickers: [], sector: "semiconductors"
- "banking stocks JPM BAC" → tickers: [JPM, BAC], sector: "banking"

STEP 2: TICKER RESOLUTION
- Convert any identified ticker words to uppercase
- If sector keywords exist, use YFinance to find 8-10 largest market cap stocks in that sector
- Final ticker list = direct tickers + sector tickers

For "ai sector" example:
- Direct tickers: [] (none found)
- Sector: "ai" → Find AI/tech companies: NVDA, AMD, GOOGL, MSFT, AAPL, META, TSLA, etc.

STEP 3: REDDIT DATA PROCESSING
- Filter reddit_data to last 24h: {data['now_utc']} minus 24 hours
- For each final ticker, scan all posts/comments for mentions
- Calculate sentiment metrics for each ticker

STEP 4: ENSURE NON-EMPTY RESULTS
- The tickers array must NOT be empty
- If no tickers found after steps 1-2, use default popular tickers
- Each TickerSocialInsight must have realistic data

Reddit data: {json.dumps(reddit_data)}
Current time: {data['now_utc']}
    """),
    use_json_mode=True,
    response_model=SentimentSnapshot,
    
)

# %%
input_query = 'NVDA'

# %%
response: RunResponse = reddit_sentiment_agent.run(input_query)

# Print the response in markdown format
# pprint_run_response(response)
print(response.content)
# Out:
# tickers=[TickerSocialInsight(symbol='NVDA', mentions=350, avg_sentiment=0.15, bullish_sentiment=0.4, bearish_sentiment=-0.2, volume_change_pct=5.0, summary='Mixed sentiment observed, with notable discussion around AI prospects and recent market performance.')]

# %%
reddit_sentiment_data = response.content

# %%
class ComponentBreakdown(BaseModel):
    """Granular factors feeding the value‑risk signal (0 = worst … 1 = best)."""
    valuation:         float = Field(..., ge=0.0, le=1.0)
    growth:            float = Field(..., ge=0.0, le=1.0)
    profitability:     float = Field(..., ge=0.0, le=1.0)
    leverage:          float = Field(..., ge=0.0, le=1.0)
    cash_flow:         float = Field(..., ge=0.0, le=1.0)
    shareholder_return:float = Field(..., ge=0.0, le=1.0)
    red_flag:          float = Field(..., ge=0.0, le=1.0,
                                     description="Higher = greater risk red flags")

# %%
class ValueRiskInsight(BaseModel):
    """
    High‑level fundamental outlook from the ‘value_risk’ agent.
    
    * **sentiment**: −1 = strongly bearish … +1 = strongly bullish  
    * **confidence**: model certainty (0…1)
    """
    symbol: str = Field(..., description="Ticker symbol, e.g. TSLA.")
    sentiment: float = Field(
        ..., ge=-1.0, le=1.0, description="Overall stance (−1 bear … +1 bull)."
    )
    confidence: float = Field(
        ..., ge=0.0, le=1.0, description="Prediction confidence (0…1)."
    )
    component_breakdown: ComponentBreakdown
    rationale: str = Field(
        ..., description="≤ 45‑word natural‑language justification of the score."
    )

# %%
class FinancialAnalysisResult(BaseModel):
    """Collection of financial analysis results."""
    results: List[ValueRiskInsight] = Field(..., description="List of financial analysis insights for all analyzed tickers.")
    window: str = Field(default="last_24h", description="Time window for the analysis.")

value_risk_agent = Agent(
    model=model,
    tools=[
        YFinanceTools(
           enable_all=True
        ),
        DuckDuckGoTools()
    ],
    instructions=dedent("""
You are the **Value / Risk Analyst**, a veteran fundamental PM.

──────────── INPUT FORMAT ────────────
<free‑text phrase>                       # e.g. “ai sector” or “NVDA AMD”

──────────── PRE‑PARSE RULES ────────────
• Extract 1‑to‑5 letter, case‑insensitive tokens → tickers (e.g. “nvda” → NVDA).
• Remaining words → sector keyword(s).

──────────── TICKER RESOLUTION ────────────
1. If at least one ticker extracted → use those.
2. ELSE (sector only):
   – If sector ∈ predefined map below, use those tickers.
   – Otherwise, fetch up to **10** largest‑cap tickers that have
     `sector == <keyword>` via yfinance screener.  
   Predefined sector map example  
   {"ai": ["NVDA","AMD","GOOGL","MSFT"],  
    "semiconductors": ["NVDA","AMD","INTC","TSM","QCOM"]}

**You must never ask the user for more tickers.  
If no tickers can be found after both steps, return
{ "error": "No tickers resolved from input." }**

──────────── FUNDAMENTAL SCORING ────────────
For each resolved ticker:
1. Retrieve price and fundamentals via yfinance.
2. Apply the 7‑pillar scoring table (valuation, growth, profitability,
   leverage, cash‑flow, shareholder return, red‑flag).
3. sentiment_raw = Σ(weighted pillar scores), clamp –1…+1.
4. confidence = 0.1 + 0.9*abs(sentiment).
5. rationale = one sentence (≤45 words) citing strongest + & – pillars.


    """),
    use_json_mode=True,
    response_model=FinancialAnalysisResult,
)

# %%
response: RunResponse = value_risk_agent.run(input_query)

# Print the response in markdown format
# pprint_run_response(response)
print(response)
finance_data = response.content
# Out:
# RunResponse(content=FinancialAnalysisResult(results=[ValueRiskInsight(symbol='NVDA', sentiment=-0.13, confidence=0.22, component_breakdown=ComponentBreakdown(valuation=0.1, growth=0.95, profitability=0.95, leverage=0.8, cash_flow=0.95, shareholder_return=0.1, red_flag=0.8), rationale='NVDA shows strong growth, profitability, and cash flow, but its valuation is high, shareholder return is low, and there are notable governance red flags.')], window='last_24h'), content_type='FinancialAnalysisResult', thinking=None, reasoning_content=None, event='RunResponse', messages=[Message(role='system', content='<instructions>\n\nYou are the **Value\u202f/\u202fRisk Analyst**, a veteran fundamental PM.\n\n──────────── INPUT FORMAT ────────────\n<free‑text phrase>                       # e.g. “ai sector” or “NVDA AMD”\n\n──────────── PRE‑PARSE RULES ────────────\n• Extract 1‑to‑5 letter, case‑insensitive tokens → tickers (e.g. “nvda” → NVDA).\n• Remaining words → sector keyword(s).\n\n──────────── TICKER RESOLUTION ────────────\n1. If at least one ticker extracted → use those.\n2. ELSE (sector only):\n   – If sector ∈ predefined map below, use those tickers.\n   – Otherwise, fetch up to **10** largest‑cap tickers that have\n     `sector == <keyword>` via yfinance screener.  \n   Predefined sector map example  \n   {"ai": ["NVDA","AMD","GOOGL","MSFT"],  \n    "semiconductors": ["NVDA","AMD","INTC","TSM","QCOM"]}\n\n**You must never ask the user for more tickers.  \nIf no tickers can be found after both steps, return\n{ "error": "No tickers resolved from input." }**\n\n──────────── FUNDAMENTAL SCORING ────────────\nFor each resolved ticker:\n1. Retrieve price and fundamentals via yfinance.\n2. Apply the 7‑pillar scoring table (valuation, growth, profitability,\n   leverage, cash‑flow, shareholder return, red‑flag).\n3. sentiment_raw = Σ(weighted pillar scores), clamp –1…+1.\n4. confidence = 0.1 + 0.9*abs(sentiment).\n5. rationale = one sentence (≤45\u202fwords) citing strongest + & – pillars.\n\n\n\n</instructions>\n\nProvide your output as a JSON containing the following fields:\n<json_fields>\n["results", "window"]\n</json_fields>\n\nHere are the properties for each field:\n<json_field_properties>\n{\n  "results": {\n    "description": "List of financial analysis insights for all analyzed tickers.",\n    "items": {\n      "$ref": "#/$defs/ValueRiskInsight"\n    },\n    "type": "array"\n  },\n  "window": {\n    "default": "last_24h",\n    "description": "Time window for the analysis.",\n    "type": "string"\n  },\n  "$defs": {\n    "ComponentBreakdown": {\n      "valuation": {\n        "maximum": 1.0,\n        "minimum": 0.0,\n        "type": "number"\n      },\n      "growth": {\n        "maximum": 1.0,\n        "minimum": 0.0,\n        "type": "number"\n      },\n      "profitability": {\n        "maximum": 1.0,\n        "minimum": 0.0,\n        "type": "number"\n      },\n      "leverage": {\n        "maximum": 1.0,\n        "minimum": 0.0,\n        "type": "number"\n      },\n      "cash_flow": {\n        "maximum": 1.0,\n        "minimum": 0.0,\n        "type": "number"\n      },\n      "shareholder_return": {\n        "maximum": 1.0,\n        "minimum": 0.0,\n        "type": "number"\n      },\n      "red_flag": {\n        "description": "Higher = greater risk red flags",\n        "maximum": 1.0,\n        "minimum": 0.0,\n        "type": "number"\n      }\n    },\n    "ValueRiskInsight": {\n      "symbol": {\n        "description": "Ticker symbol, e.g. TSLA.",\n        "type": "string"\n      },\n      "sentiment": {\n        "description": "Overall stance (\\u22121 bear \\u2026 +1 bull).",\n        "maximum": 1.0,\n        "minimum": -1.0,\n        "type": "number"\n      },\n      "confidence": {\n        "description": "Prediction confidence (0\\u20261).",\n        "maximum": 1.0,\n        "minimum": 0.0,\n        "type": "number"\n      },\n      "component_breakdown": {\n        "$ref": "#/$defs/ComponentBreakdown"\n      },\n      ...

# %%
combined_request = f"reddit sentiments: {reddit_sentiment_data}, finance data: {finance_data}"

# %%
summarize_agent = Agent(
    model=model,
    tools=[],
    instructions=dedent("""
<instructions>
You are the **Synthesizer / Portfolio Manager**.

────────────────── INPUT ──────────────────
A single text string formatted exactly as:

reddit sentiments: <REDDIT_JSON>, finance data: <FINANCE_JSON>

• <REDDIT_JSON>  follows the schema produced by the Reddit‑Analysis Agent
  (entities ▶ symbol ▶ avg_sentiment, bullish_sentiment, bearish_sentiment,
   volume_change_pct, summary, etc.).

• <FINANCE_JSON> is a dictionary keyed by ticker symbol containing price
  and fundamental metrics (pe_ttm, forward_pe, eps_yoy_pct, etc.).

────────────────── TASKS ──────────────────
1. **Parse** the string to obtain two Python/JSON objects:
   `reddit = {...}` , `finance = {...}`.

2. **For each ticker** appearing in either object:
   • sentiment = reddit.entities[sym].avg_sentiment  (null → 0)  
   • valuation  = finance[sym].get("pe_ttm")         (null → "n/a")  
   • build a bullet‑point **Bull case** if sentiment>0.2 or pe_ttm<25.  
   • build a **Bear case** if sentiment<‑0.2 or pe_ttm>35.  
   • Add a risk note if `reddit.entities[sym].volume_change_pct` > 50 %  
     (crowd‑hype risk) or if pe_ttm is "n/a".

3. **Verdict & Size**
   • net = sentiment  
   • long if net>0.15 ; short if net<‑0.15 ; else flat.  
   • size_pct = round(net * 50) capped ±30.

4. **Compose a human‑readable Markdown block** per ticker:
    """),
    markdown=True
)

# %%
response: RunResponse = summarize_agent.run(combined_request)

# Print the response in markdown format
pprint_run_response(response)
#print(response.content)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ```json                                                                                                         │
# │ {                                                                                                               │
# │   "reddit": {                                                                                                   │
# │     "tickers": [                                                                                                │
# │       {                                                                                                         │
# │         "symbol": "TSLA",                                                                                       │
# │         "mentions": 20,                                                                                         │
# │         "avg_sentiment": -0.2,                                                                                  │
# │         "bullish_sentiment": 0.5,                                                                               │
# │         "bearish_sentiment": -0.7,                                                                              │
# │         "volume_change_pct": null,                                                                              │
# │         "summary": "Significant discussion around declining deliveries and the stock's seemingly irrational     │
# │ positive reaction, mixed sentiment."                                                                            │
# │       },                                                                                                        │
# │       {                                                                                                         │
# │         "symbol": "F",                                                                                          │
# │         "mentions": 10,                                                                                         │
# │         "avg_sentiment": 0.1,                                                                                   │
# │         "bullish_sentiment": 0.4,                                                                               │
# │         "bearish_sentiment": -0.3,                                                                              │
# │         "volume_change_pct": null,                                                                              │
# │         "summary": "Chatter focuses on strong Q2 sales but also concerns about recalls and electric vehicle     │
# │ performance."                                                                                                   │
# │       },                                                                                                        │
# │       {                                                                                                         │
# │         "symbol": "HOOD",                                                                                       │
# │         "mentions": 10,                                                                                         │
# │         "avg_sentiment": 0.7,                                                                                   │
# │         "bullish_sentiment": 0.8,                                                                               │
# │         "bearish_sentiment": -0.1,                                                                              │
# │         "volume_change_pct": null,                                                                              │
# │         "summary": "Strong bullish sentiment following a significant stock price surge, with discussion on      │
# │ platform improvements and user growth."                                                                         │
# │       },                                                                                                        │
# │       {                                                                                                         │
# │         "symbol": "BULL",                                                                                       │
# │         "mentions": 10,                                                                                         │
# │         "avg_sentiment": 0.8,                                                                                   │
# │         "bullish_sentiment": 0.9,                                                                               │
# │         "bearish_sentiment": 0.0,                                                                               │
# │         "volume_change_pct": null,                                                                              │
# │         "summary": "Highly bullish sentiment with focus on large call positions and positive earnings           │
# │ expectations."                                                                                                  │
# │       },                                                                                                        │
# │       {                                                                                                         │
# │         "symbol": "MSTR",                                                                                       │
# │         "mentions": 5,                                                                                          │
# │         "avg_sentiment": 0.6,                                                                                   │
# │         "bullish_sentiment": 0.7,                                                                               │
# │         "bearish_sentiment": 0.0,                                                                               │
# │         "volume_change_pct": null,                                                                              │
# │         "summary": "Bullish sentiment driven by a large YOLO position and reported overnight gains."            │
# │       },                                                                                                        │
# │       {                                                                                                         │
# │         "symbol": "META",                                                                                       │
# │         "mentions": 10,                                                                                         │
# │         "avg_sentiment": 0.3,                                                                                   │
# │         "bullish_sentiment": 0.6,                                                                               │
# │         "bearish_sentiment": -0.2,                                                                              │
# │         "volume_change_pct": null,                                                                              │
# │         "summary": "Mixed sentiment regarding large investments in AI/metaverse, balanced by recognition of     │
# │ strong financial performance and future potential."                                                             │
# │       },                                                                                                        │
# │       {                                                                                                         │
# │         "symbol": "INTC",                                                                                       │
# │         "mentions": 10,                                                                                         │
# │         "avg_sentiment": -0.7,                                                                                  │
# │         "bullish_sentiment": 0.0,                                                                               │
# │         "bearish_sentiment": -0.8,                                                                              │
# │         "volume_change_pct": null,                                                                              │
# │         "summary": "Predominantly negative sentiment surrounding manufacturing technology writedowns and        │
# │ ongoing business challenges."                                                                                   │
# │       },                                                                                                        │
# │       {                                                                                                         │
# │         "symbol": "CNC",                                                                                        │
# │         "mentions": 5,                                                                                          │
# │         "avg_sentiment": -0.9,                                                                                  │
# │         "bullish_sentiment": 0.0,                                                                               │
# │         "bearish_sentiment": -0.9,                                                                              │
# │         "volume_change_pct": null,                                                                              │
# │         "summary": "Extremely negative sentiment due to a massive stock price drop following withdrawn guidance │
# │ and concerns about growth and costs."                                                                           │
# │       },                                                                                                        │
# │       {                                                                                                         │
# │         "symbol": "UNH",                                                                                        │
# │         "mentions": 5,                                                                                          │
# │         "avg_sentiment": -0.4,                                                                                  │
# │         "bullish_sentiment": 0.0,                                                                               │
# │         "bearish_sentiment": -0.6,                                                                              │
# │         "volume_change_pct": null,                                                                              │
# │         "summary": "Negative sentiment related to broader healthcare sector news and risks, though perceived as │
# │ less severely impacted than some peers."                                                                        │
# │       },                                                                                                        │
# │       {                                                                                                         │
# │         "symbol": "BAC",                                                                                        │
# │         "mentions": 3,                                                                                          │
# │         "avg_sentiment": 0.5,                                                                                   │
# │         "bullish_sentiment": 0.6,                                                                               │
# │         "bearish_sentiment": 0.0,                                                                               │
# │         "volume_change_pct": null,                                                                              │
# │         "summary": "Positive sentiment specifically regarding a recently announced dividend increase."          │
# │       },                                                                                                        │
# │       {                                                                                                         │
# │         "symbol": "JPM",                                                                                        │
# │         "mentions": 3,                                                                                          │
# │         "avg_sentiment": 0.5,                                                                                   │
# │         "bullish_sentiment": 0.6,                                                                               │
# │         "bearish_sentiment": 0.0,                                                                               │
# │         "volume_change_pct": null,                                                                              │
# │         "summary": "Positive sentiment related to a dividend increase and share buyback program."               │
# │       }                                                                                                         │
# │     ]                                                                                                           │
# │   },                                                                                                            │
# │   "finance": {                                                                                                  │
# │     "error": "No tickers resolved from input."                                                                  │
# │   }                                                                                                             │
# │ }                                                                                                               │
# │ ```                                                                                                             │
# │ ---                                                                                                             │
# │ ## TSLA                                                                                                         │
# │                                                                                                                 │
# │ **Sentiment:** -0.2                                                                                             │
# │                                                                                                                 │
# │ **Valuation:** n/a                                                                                              │
# │                                                                                                                 │
# │ **Bull Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Bear Case:**                                                                                                  │
# │ *   Reddit sentiment is bearish, driven by discussion around declining deliveries.                              │
# │                                                                                                                 │
# │ **Risks:**                                                                                                      │
# │ *   Valuation data is not available.                                                                            │
# │                                                                                                                 │
# │ **Verdict & Size:**                                                                                             │
# │ *   Net Sentiment: -0.2                                                                                         │
# │ *   Verdict: Short                                                                                              │
# │ *   Size: -10%                                                                                                  │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │ ## F                                                                                                            │
# │                                                                                                                 │
# │ **Sentiment:** 0.1                                                                                              │
# │                                                                                                                 │
# │ **Valuation:** n/a                                                                                              │
# │                                                                                                                 │
# │ **Bull Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Bear Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Risks:**                                                                                                      │
# │ *   Valuation data is not available.                                                                            │
# │                                                                                                                 │
# │ **Verdict & Size:**                                                                                             │
# │ *   Net Sentiment: 0.1                                                                                          │
# │ *   Verdict: Flat                                                                                               │
# │ *   Size: 5%                                                                                                    │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │ ## HOOD                                                                                                         │
# │                                                                                                                 │
# │ **Sentiment:** 0.7                                                                                              │
# │                                                                                                                 │
# │ **Valuation:** n/a                                                                                              │
# │                                                                                                                 │
# │ **Bull Case:**                                                                                                  │
# │ *   Reddit sentiment is strongly bullish following a stock price surge, focused on platform improvements and    │
# │ user growth.                                                                                                    │
# │                                                                                                                 │
# │ **Bear Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Risks:**                                                                                                      │
# │ *   Valuation data is not available.                                                                            │
# │                                                                                                                 │
# │ **Verdict & Size:**                                                                                             │
# │ *   Net Sentiment: 0.7                                                                                          │
# │ *   Verdict: Long                                                                                               │
# │ *   Size: 30%                                                                                                   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │ ## BULL                                                                                                         │
# │                                                                                                                 │
# │ **Sentiment:** 0.8                                                                                              │
# │                                                                                                                 │
# │ **Valuation:** n/a                                                                                              │
# │                                                                                                                 │
# │ **Bull Case:**                                                                                                  │
# │ *   Reddit sentiment is highly bullish, with focus on large call positions and positive earnings expectations.  │
# │                                                                                                                 │
# │ **Bear Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Risks:**                                                                                                      │
# │ *   Valuation data is not available.                                                                            │
# │                                                                                                                 │
# │ **Verdict & Size:**                                                                                             │
# │ *   Net Sentiment: 0.8                                                                                          │
# │ *   Verdict: Long                                                                                               │
# │ *   Size: 30%                                                                                                   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │ ## MSTR                                                                                                         │
# │                                                                                                                 │
# │ **Sentiment:** 0.6                                                                                              │
# │                                                                                                                 │
# │ **Valuation:** n/a                                                                                              │
# │                                                                                                                 │
# │ **Bull Case:**                                                                                                  │
# │ *   Reddit sentiment is bullish, driven by discussions of large positions and reported overnight gains.         │
# │                                                                                                                 │
# │ **Bear Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Risks:**                                                                                                      │
# │ *   Valuation data is not available.                                                                            │
# │                                                                                                                 │
# │ **Verdict & Size:**                                                                                             │
# │ *   Net Sentiment: 0.6                                                                                          │
# │ *   Verdict: Long                                                                                               │
# │ *   Size: 30%                                                                                                   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │ ## META                                                                                                         │
# │                                                                                                                 │
# │ **Sentiment:** 0.3                                                                                              │
# │                                                                                                                 │
# │ **Valuation:** n/a                                                                                              │
# │                                                                                                                 │
# │ **Bull Case:**                                                                                                  │
# │ *   Reddit sentiment is bullish, recognizing strong financial performance and future potential despite mixed    │
# │ views on large investments.                                                                                     │
# │                                                                                                                 │
# │ **Bear Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Risks:**                                                                                                      │
# │ *   Valuation data is not available.                                                                            │
# │                                                                                                                 │
# │ **Verdict & Size:**                                                                                             │
# │ *   Net Sentiment: 0.3                                                                                          │
# │ *   Verdict: Long                                                                                               │
# │ *   Size: 15%                                                                                                   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │ ## INTC                                                                                                         │
# │                                                                                                                 │
# │ **Sentiment:** -0.7                                                                                             │
# │                                                                                                                 │
# │ **Valuation:** n/a                                                                                              │
# │                                                                                                                 │
# │ **Bull Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Bear Case:**                                                                                                  │
# │ *   Reddit sentiment is predominantly negative, surrounding manufacturing technology writedowns and ongoing     │
# │ challenges.                                                                                                     │
# │                                                                                                                 │
# │ **Risks:**                                                                                                      │
# │ *   Valuation data is not available.                                                                            │
# │                                                                                                                 │
# │ **Verdict & Size:**                                                                                             │
# │ *   Net Sentiment: -0.7                                                                                         │
# │ *   Verdict: Short                                                                                              │
# │ *   Size: -30%                                                                                                  │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │ ## CNC                                                                                                          │
# │                                                                                                                 │
# │ **Sentiment:** -0.9                                                                                             │
# │                                                                                                                 │
# │ **Valuation:** n/a                                                                                              │
# │                                                                                                                 │
# │ **Bull Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Bear Case:**                                                                                                  │
# │ *   Reddit sentiment is extremely negative due to a massive price drop following withdrawn guidance and         │
# │ growth/cost concerns.                                                                                           │
# │                                                                                                                 │
# │ **Risks:**                                                                                                      │
# │ *   Valuation data is not available.                                                                            │
# │                                                                                                                 │
# │ **Verdict & Size:**                                                                                             │
# │ *   Net Sentiment: -0.9                                                                                         │
# │ *   Verdict: Short                                                                                              │
# │ *   Size: -30%                                                                                                  │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │ ## UNH                                                                                                          │
# │                                                                                                                 │
# │ **Sentiment:** -0.4                                                                                             │
# │                                                                                                                 │
# │ **Valuation:** n/a                                                                                              │
# │                                                                                                                 │
# │ **Bull Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Bear Case:**                                                                                                  │
# │ *   Reddit sentiment is negative, related to broader healthcare sector news and risks.                          │
# │                                                                                                                 │
# │ **Risks:**                                                                                                      │
# │ *   Valuation data is not available.                                                                            │
# │                                                                                                                 │
# │ **Verdict & Size:**                                                                                             │
# │ *   Net Sentiment: -0.4                                                                                         │
# │ *   Verdict: Short                                                                                              │
# │ *   Size: -20%                                                                                                  │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │ ## BAC                                                                                                          │
# │                                                                                                                 │
# │ **Sentiment:** 0.5                                                                                              │
# │                                                                                                                 │
# │ **Valuation:** n/a                                                                                              │
# │                                                                                                                 │
# │ **Bull Case:**                                                                                                  │
# │ *   Reddit sentiment is positive, specifically regarding a recently announced dividend increase.                │
# │                                                                                                                 │
# │ **Bear Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Risks:**                                                                                                      │
# │ *   Valuation data is not available.                                                                            │
# │                                                                                                                 │
# │ **Verdict & Size:**                                                                                             │
# │ *   Net Sentiment: 0.5                                                                                          │
# │ *   Verdict: Long                                                                                               │
# │ *   Size: 25%                                                                                                   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │ ## JPM                                                                                                          │
# │                                                                                                                 │
# │ **Sentiment:** 0.5                                                                                              │
# │                                                                                                                 │
# │ **Valuation:** n/a                                                                                              │
# │                                                                                                                 │
# │ **Bull Case:**                                                                                                  │
# │ *   Reddit sentiment is positive, related to a dividend increase and share buyback program.                     │
# │                                                                                                                 │
# │ **Bear Case:** None                                                                                             │
# │                                                                                                                 │
# │ **Risks:**                                                                                                      │
# │ *   Valuation data is not available.                                                                            │
# │                                                                                                                 │
# │ **Verdict & Size:**                                                                                             │
# │ *   Net Sentiment: 0.5                                                                                          │
# │ *   Verdict: Long                                                                                               │
# │ *   Size: 25%                                                                                                   │
# │ ```                                                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
